# %%
import os
os.chdir('..')

from Experiments import *
from tqdm import tqdm
from Models import *
from utils import *
from DataGenerator import *
from DataLoader import *

# %%
# a, b = mnist_training_analysis([16], pre_path='test_results/', epochs=5)

# %%
scale = 10
loc = 0
normal_dist = True
archs = [
    # (100, [100]),
    (2, [100 for _ in range(15)]),
    # (2, [16, 64, 256, 256, 256, 256]),
    # (100, [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100])
    # (2, [4])
    # (2, [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100])
]

# %%
results = [one_random_experiment(i, exps=5, num=1000, one=False, pre_path='test_results/', normal_dist=normal_dist, loc=loc, scale=scale, projection_analysis_bool=True, model_type='mlp', exp_type='plane') for i in tqdm(archs)]
print("DONE")

# [before_after_training_experiment(i, pre_path='test_results/', num=100, epochs=5, normal_dist=normal_dist, loc=0, scale=scale) for i in archs]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# test_results/plane_mean_0_std10/bias_0.0001/random_data_random_untrained_networkbias0.0001_exps5_num1000_center_0_mlp_(2, [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100])/
#  40%|████      | 2/5 [02:03<03:04, 61.50s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = [one_random_experiment(i, exps=5, num=1000, one=False, pre_path='test_results/', normal_dist=normal_dist, loc=loc, scale=scale, projection_analysis_bool=True, model_type='mlp', exp_type='plane') for i in tqdm(archs)]
#       2 print("DONE")
#
# Cell In[3], line 1, in <listcomp>(.0)
# ...

# %%
# animate_histogram(results, 'hidden Layers', pre_path='test_results/')
