# %%
from Experiments import *
from tqdm import tqdm
from Models import *
from utils import *
from DataGenerator import *
from DataLoader import *

# %%
mnist_training_analysis((784, [128, 64]), pre_path='test_results/', epochs=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mnist_training_analysis((784, [128, 64]), pre_path='test_results/', epochs=4)
#
# File ~/hidden_symmetries/DeepReLuSymmetries/Experiments.py:184, in mnist_training_analysis(architecture, epochs, pre_path)
#     181 n_in = architecture[0]
#     182 simple_model = MLP_mnist(hiddens=architecture[1])
# --> 184 train_loader, val_loader, test_loader = get_mnist_data_loaders()
#     186 train_x = train_loader.dataset.dataset.data[train_loader.dataset.indices,:,:].to(device)
#     187 val_x = val_loader.dataset.dataset.data[val_loader.dataset.indices,:,:].to(device)
#
# File ~/hidden_symmetries/DeepReLuSymmetries/DataLoader.py:8, in get_mnist_data_loaders(batch_size)
#       6 def get_mnist_data_loaders(batch_size=256):
#       7     # define transforms
# ----> 8     train, val, test = creat_mnist_data()
# ...

# %%
scale = 1
normal_dist = True
archs = [
    # (100, [100]),
    # (100, [100, 100]),
    # (2, [4])
    (105, [100, 100, 100, 100, 100, 100, 100, 100, 98])
]

# %%
results = [one_random_experiment(i, exps=5, num=1000, one=False, pre_path='test_results/', normal_dist=normal_dist, loc=0, scale=scale, projection_analysis_bool=True) for i in tqdm(archs)]
print("DONE")

# [before_after_training_experiment(i, pre_path='test_results/', num=100, epochs=5, normal_dist=normal_dist, loc=0, scale=scale) for i in archs]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# animate_histogram(results, 'hidden Layers', pre_path='test_results/')
