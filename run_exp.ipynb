# %%
from Experiments import *
from tqdm import tqdm
from Models import *
from utils import *
from DataGenerator import *
from DataLoader import *

# %%
mnist_training_analysis([128, 64], pre_path='test_results/', epochs=4)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mnist_training_analysis([128, 64], pre_path='test_results/', epochs=4)
#
# File ~/hidden_symmetries/DeepReLuSymmetries/Experiments.py:186, in mnist_training_analysis(architecture, epochs, pre_path)
#     183 test_x = test_loader.dataset.data.to(device)
#     185 over_path = this_path + "untrained_"
# --> 186 whole_data_analysis_forward_pass(simple_model, 'train', over_path=over_path, dataset_here=train_x)
#     187 whole_data_analysis_forward_pass(simple_model, 'val', over_path=over_path, dataset_here=val_x)
#     188 whole_data_analysis_forward_pass(simple_model, 'test', over_path=over_path, dataset_here=test_x)
#
# File ~/hidden_symmetries/DeepReLuSymmetries/ForwardPass.py:39, in whole_data_analysis_forward_pass(model, mode, over_path, dataset_here, scale)
#      37 model.reset()
#      38 model.extra()
# ---> 39 model(dataset_here)
#      40 additive_act, eigenvalues_count, eigens, list_pca_2d, list_pca_3d, list_random_2d, list_random_3d, distances, dis_stats = model.post_forward_neuron_activation_analysis(dataset_here)
#      42 this_path = over_path + mode + '_'
#
# File ~/.conda/envs/py38_ssl/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/hidden_symmetries/DeepReLuSymmetries/Models.py:15, in MLP_mnist.forward(self, x)
#      13 def forward(self, x):
#      14     # flatten_x = torch.flatten(x, start_dim=1)
# ---> 15     output = self.layers(x.flatten(1))
#      16     return output
#
# File ~/.conda/envs/py38_ssl/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/py38_ssl/lib/python3.8/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/.conda/envs/py38_ssl/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/hidden_symmetries/DeepReLuSymmetries/ParentModels.py:38, in CustomLinearWithActivation.forward(self, input)
#      36 self.non_zero += np.sum((deteached_version > 0), axis=0)
#      37 if self.additional_analysis:
# ---> 38   self.eigenvalues_count, self.dis_values, self.dis_stats = additional_analysis_for_full_data(deteached_version)
#      39 if self.extra:
#      40   self.eigenvalues, self.plot_list_pca_2d, self.plot_list_pca_3d, self.plot_list_random_2d, self.plot_list_random_3d = projection_analysis_for_full_data(deteached_version, True)
#
# File ~/hidden_symmetries/DeepReLuSymmetries/utils.py:299, in additional_analysis_for_full_data(this_data)
#     297 def additional_analysis_for_full_data(this_data):
#     298     res = count_near_zero_eigenvalues(this_data, return_eigenvalues=False)
# --> 299     distances_this_data = cdist(this_data, this_data)[np.triu_indices(this_data.shape[0], k=1)]
#     300     return res, distances_this_data / np.mean(distances_this_data), [np.mean(distances_this_data), np.max(distances_this_data), np.min(distances_this_data)]
#
# File ~/.conda/envs/py38_ssl/lib/python3.8/site-packages/scipy/spatial/distance.py:2929, in cdist(XA, XB, metric, out, **kwargs)
#    2927 if metric_info is not None:
#    2928     cdist_fn = metric_info.cdist_func
# -> 2929     return cdist_fn(XA, XB, out=out, **kwargs)
#    2930 elif mstr.startswith("test_"):
#    2931     metric_info = _TEST_METRICS.get(mstr, None)
#
# MemoryError: Unable to allocate 18.6 GiB for an array with shape (50000, 50000) and data type float64

# %%
scale = 1
normal_dist = True
archs = [
    # (100, [100]),
    # (100, [100, 100]),
    # (2, [4])
    (105, [100, 100, 100, 100, 100, 100, 100, 100, 98])
]

# %%
results = [one_random_experiment(i, exps=5, num=1000, one=False, pre_path='test_results/', normal_dist=normal_dist, loc=0, scale=scale, projection_analysis_bool=True) for i in tqdm(archs)]
print("DONE")

# [before_after_training_experiment(i, pre_path='test_results/', num=100, epochs=5, normal_dist=normal_dist, loc=0, scale=scale) for i in archs]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# animate_histogram(results, 'hidden Layers', pre_path='test_results/')
