# %%
from Experiments import *
from tqdm import tqdm
from Models import *
from utils import *

# %%
x, y = create_random_data(20, 1000, normal_dsit=True, loc=0, scale=1)

# %%
scale = 1
normal_dist = True
archs = [
    # (100, [100]),
    # (100, [100, 100]),
    # (100, [100, 100, 100]),
    (100, [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100])
]

# %%
results = [one_random_experiment(i, exps=10, one=False, pre_path='test_results/', normal_dist=normal_dist, loc=0, scale=scale) for i in tqdm(archs)]
print("DONE")

# [before_after_training_experiment(i, pre_path='test_results/', num=100, epochs=5, normal_dist=normal_dist, loc=0, scale=scale) for i in archs]
# Out:
# ...
# 100%|██████████| 1/1 [03:26<00:00, 206.69s/it]
# DONE

# %%
# animate_histogram(results, 'hidden Layers', pre_path='test_results/')
