# %%
from Experiments import *
from tqdm import tqdm
from Models import *
from utils import *
from DataGenerator import *
from DataLoader import *

# %%
# a, b = mnist_training_analysis([16], pre_path='test_results/', epochs=5)

# %%
scale = 50
normal_dist = True
archs = [
    # (100, [100]),
    (100, [100, 100, 100, 100, 100, 100, 2048])
    # (2, [4])
    # (2, [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100])
]

# %%
results = [one_random_experiment(i, exps=5, num=100, one=False, pre_path='test_results/', normal_dist=normal_dist, loc=-20, scale=scale, projection_analysis_bool=True) for i in tqdm(archs)]
print("DONE")

# [before_after_training_experiment(i, pre_path='test_results/', num=100, epochs=5, normal_dist=normal_dist, loc=0, scale=scale) for i in archs]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# test_results/normal_mean_-20_std50/bias_0.0001/random_data_random_untrained_networkbias0.0001_exps5_num100_center_-20_(100, [100, 100, 100, 100, 100, 100, 2048])/
# 100%|██████████| 1/1 [02:18<00:00, 138.67s/it]
# DONE

# %%
# animate_histogram(results, 'hidden Layers', pre_path='test_results/')
